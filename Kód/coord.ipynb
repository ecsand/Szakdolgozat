# %%
import pandas as pd
import os
from openpyxl import load_workbook
import numpy as np
import re
wb1= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\dfveg_latest.xlsx")
sheet1 = wb1.active 

dflatest = pd.DataFrame(sheet1.values)

# %%
df = dflatest.iloc[: , 2:]
print(len(df))
df = df[df[8].str.contains(r"(?=.*Malacca)(?=.*Singapore)|SOMS|S0MS", na=False)]
#df = df[df[8].str.contains("SOMS|S0MS|Straits ofMalacca &Singapore|Straitsof Malacca andSingapore|Straits ofMalacca andSingapore|Straits of Malacca and Singapore|Straits of Malacca & Singapore", na=False)]
df.head()
# Out:
# 1743
#              2                                                  3           4  \
# 40       CAT 3  Lapald Tug boat Singapore 941 2555\n472\n}NC 2...   15/0/2010
# 57       CAT 2         Britoil ó2 Tug boat Singapore 9352444\n497  28/06/2010
# 125      CAT 2  AOS Tl30 I\nTug boat Singapore 953 1674\n165\n...  08/12/2010
# 129      CAT 2  Surya Wira  I Tug boat Indonesia\n9 183233\n10...  23/12/2010
# 135  Attempted                    Tanker Indonesia 9006904\n53772  22/01/2010
#
#             5              6               7  \
# 40   2015 hrs    01° 15.4' N    104° 10.9' E
# 57   1150 hrs     1° 6.23' N   103° 44.69’ E
# 125  0428 hrs  01° 12. 15’ N   103° 33.40’ E
# 129  0340 hrs   01° 11.29' N  103°  34.47' E
# 135  2344 hrs  01°  14.56’ N   104° 05.19' E
#
#                                                      8                 9
# 40    Singapore Strait VTIS East, Straits of Malacc...  &TUG BOAT &BARGE
# ...

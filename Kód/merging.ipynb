# %%
import pandas as pd
import os
from openpyxl import load_workbook
import numpy as np
import re

wb2010= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2010.xlsx")
sheet2010 = wb2010.active 

df2010 = pd.DataFrame(sheet2010.values)

wb2011= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2011.xlsx")
sheet2011 = wb2011.active 

df2011 = pd.DataFrame(sheet2011.values)

wb2012= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2012.xlsx")
sheet2012 = wb2012.active 

df2012 = pd.DataFrame(sheet2012.values)

wb2013= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2013.xlsx")
sheet2013 = wb2013.active 

df2013 = pd.DataFrame(sheet2013.values)

wb2014= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2014.xlsx")
sheet2014 = wb2014.active 

df2014 = pd.DataFrame(sheet2014.values)

wb2015= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2015.xlsx")
sheet2015 = wb2015.active 

df2015 = pd.DataFrame(sheet2015.values)

wb2016= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2016.xlsx")
sheet2016 = wb2016.active 

df2016 = pd.DataFrame(sheet2016.values)


wb2017= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2017.xlsx")
sheet2017 = wb2017.active 

df2017 = pd.DataFrame(sheet2017.values)


wb2018= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2018.xlsx")
sheet2018 = wb2018.active 

df2018 = pd.DataFrame(sheet2018.values)


wb2019= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2019.xlsx")
sheet2019 = wb2019.active 

df2019 = pd.DataFrame(sheet2019.values)


wb2020= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2020.xlsx")
sheet2020 = wb2020.active 

df2020 = pd.DataFrame(sheet2020.values)

wb2021= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2021.xlsx")
sheet2021 = wb2021.active 

df2021 = pd.DataFrame(sheet2021.values)

# %%
df1021=pd.concat([df2010, df2011, df2012, df2013, df2014, df2015, df2016, df2017, df2018, df2019, df2020, df2021], ignore_index=True, axis=0)

#cols=[2, 3, 6, 7, 8, 9, 10]
df1021 = df1021.iloc[:, [1, 2] + list(range(5, 10))]

dff1021=df1021.iloc[1: , :]

print(dff1021.head())
dff1021.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df1021.xlsx")
# Out:
#        1                                                  2           5  \
# 1  CAT 3    Sonyo Container ship Singapore\n9 178393\n16705  04/01/2010
# 2  CAT 3  Bow Sagomi Chemical tanker Panama\n93799 I I\n...  09/01/2010
# 3  CAT 3  TSC     Twi Container ship United Kingdom 9I 6...  12/01/2010
# 4  CAT 3    PFS Narayana Bulk carrier India\n8130667\n28330  13/01/2010
# 5  CAT 3    Crone island Bulk carrier Panama 9478482\n20242  15/01/2010
#
#           6             7               8  \
# 1  0200 hrs  06" 05.86' S  106" 54. 15' E
# 2  0400 hrs           N/A             N/A
# 3  0205 hrs    10"  15’ N     107" 0.4’ E
# 4  0415 hrs   01" 21.4' S    116" 59.3' E
# 5  0300 hrs     05" 31' S      105" 18' E
#
#                                                    9
# 1   Koja Continer Terminal, Tanjung Priok, Indonesia
# 2        Petrokimia Terminal, Gresik Port, Indonesia
# 3                   Year Vung Tau Anchorage, Vietnam
# 4     Near North Pulau Laut Coal Terminal, Indonesia
# ...

# %%
wb2022= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2022.xlsx")
sheet2022 = wb2022.active 
df2022 = pd.DataFrame(sheet2022.values)
df2022.columns=df2022.iloc[0]
df2022=df2022[['CAT', 'Type of ship', 'Date of incident', 'Time of incident', 'Latitude', 'Longitude', 'Area location']]
df2022=df2022.iloc[1: , :]
df2022.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2022_2.xlsx") 

wb2022= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2022_2.xlsx")
sheet2022 = wb2022.active 
df2022 = pd.DataFrame(sheet2022.values)


wb2023= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2023.xlsx")
sheet2023 = wb2023.active 
df2023 = pd.DataFrame(sheet2023.values)
df2023.columns=df2023.iloc[0]
df2023=df2023[['CAT', 'Type of ship', 'Date of\nincident', 'Time of\nincident', 'Latitude', 'Longitude', 'Area location']]
df2023=df2023.iloc[1: , :]


wb2024= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2024.xlsx")
sheet2024 = wb2024.active 

df2024 = pd.DataFrame(sheet2024.values)
df2024.columns=df2024.iloc[0]
df2024=df2024[['CAT', 'Type of ship', 'Date of\nincident', 'Time of\nincident', 'Latitude', 'Longitude', 'Area location']]

df2024=df2024.iloc[1: , :]
df2024.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2024_2.xlsx") 

df2023.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2023_2.xlsx") 

wb2023= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2023_2.xlsx")
sheet2023 = wb2023.active 
df2023 = pd.DataFrame(sheet2023.values)

df2024.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2022_2.xlsx") 

wb2024= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2024_2.xlsx")
sheet2024 = wb2024.active 
df2024 = pd.DataFrame(sheet2024.values)

df2224 = pd.concat([df2022, df2023, df2024], ignore_index=True, axis=0)


wb1=load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df1021.xlsx")
sheet1 = wb1.active 
df1 = pd.DataFrame(sheet1.values)

wb2=load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2224.xlsx")
sheet2 = wb2.active 
df2 = pd.DataFrame(sheet2.values)


df1=df1.iloc[1: , :]


df2=df2.iloc[2: , :]


df= pd.concat([df1, df2], ignore_index=True, axis=0)
df = df.loc[df[1] != 'CAT']
df[1]=df[1].astype(str)
df = df.loc[df[1] != 'None']
df.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\dfvegso.xlsx")

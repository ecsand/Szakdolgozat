# %%
import pandas as pd
import os
from openpyxl import load_workbook
import numpy as np
import re

# %%
#dataset import


wb2010= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2010.xlsx")
sheet2010 = wb2010.active 

df2010 = pd.DataFrame(sheet2010.values) #done

wb2011= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2011.xlsx")
sheet2011 = wb2011.active 

df2011 = pd.DataFrame(sheet2011.values) #done

wb2012= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2012.xlsx")
sheet2012 = wb2012.active

df2012a = pd.DataFrame(sheet2012.values)

wb2013= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2013.xlsx")
sheet2013 = wb2013.active

df2013a = pd.DataFrame(sheet2013.values)

wb2014= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2014.xlsx")
sheet2014 = wb2014.active

df2014a = pd.DataFrame(sheet2014.values)

wb2015= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2015.xlsx")
sheet2015 = wb2015.active 

df2015 = pd.DataFrame(sheet2015.values) #done


wb2016= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2016.xlsx")
sheet2016 = wb2016.active

df2016a = pd.DataFrame(sheet2016.values)


wb2017= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2017.xlsx")
sheet2017 = wb2017.active

df2017 = pd.DataFrame(sheet2017.values) #done


wb2018= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2018.xlsx")
sheet2018 = wb2018.active

df2018a = pd.DataFrame(sheet2018.values)


wb2019= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2019.xlsx")
sheet2019 = wb2019.active

df2019a = pd.DataFrame(sheet2019.values)


wb2020= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2020.xlsx")
sheet2020 = wb2020.active

df2020a = pd.DataFrame(sheet2020.values)


wb2021= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2021.xlsx")
sheet2021 = wb2021.active

df2021a = pd.DataFrame(sheet2021.values)


wb2022= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2022.xlsx")
sheet2022 = wb2022.active

df2022 = pd.DataFrame(sheet2022.values)


wb2023= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2023.xlsx")
sheet2023 = wb2023.active

df2023 = pd.DataFrame(sheet2023.values)


wb2024= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\2024.xlsx")
sheet2024 = wb2024.active

df2024 = pd.DataFrame(sheet2024.values)

#2020-21, a többi sétagalopp, ill. persze az összeillesztés

# %%
w2010= load_workbook("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2010.xlsx")
shee2010 = wb2010.active 

df2010 = pd.DataFrame(sheet2010.values) #done

# %%
#2021
#2018
a=[]
b=[] #cat
c=[] #name
d=[] #datetime
e=[] #latlong
f=0

for f in range(len(df2021a)):
    itemb = ""
    itemc = ""
    itemd = ""
    iteme = ""

    while f + 1 < len(df2021a) and df2021a[0][f+1] == df2021a[0][f]:   
        itemb += str(df2021a[1][f])
        itemc += str(df2021a[2][f])
        itemd += str(df2021a[3][f])
        iteme += str(df2021a[4][f])
        f += 1

    if f + 1 < len(df2021a) and df2021a[0][f+1] != df2021a[0][f]: 
        itema = df2021a[0][f]  
        itemb += str(df2021a[1][f])
        itemc += str(df2021a[2][f])
        itemd += str(df2021a[3][f])
        iteme += str(df2021a[4][f])

        a.append(itema)   
        b.append(itemb)
        c.append(itemc)
        d.append(itemd)
        e.append(iteme)
        

aa=[]
bb=[]
cc=[]
dd=[]
ee=[]
for aaa, bbb, ccc, ddd, eee in zip(a, b, c, d, e):
    if aaa not in aa:
        aa.append(aaa)
        bb.append(bbb)
        cc.append(ccc)
        dd.append(ddd)
        ee.append(eee)

df2021=pd.DataFrame()
df2021["CAT"]=bb
df2021["CAT"]=df2021["CAT"].str.replace("None", "")
df2021["name"]=cc
df2021["name"]=df2021["name"].str.replace("None", "")
df2021["datetime"]=dd
df2021["datetime"]=df2021["datetime"].str.replace("None", "").str.replace("00:00:00", "")
df2021["latlong"]=ee
df2021["latlong"]=df2021["latlong"].str.replace("None", "")

#separating date and time + creating datetime
list=[]
date=[]
time=[]
for x in df2021["datetime"]:
    if '\n' in x:
        datetime=x.split('\n')
        date.append(datetime[0])
        time.append(datetime[1])
    elif " " in x:
        datetime=x.split(' ', 1)
        date.append(datetime[0])
        time.append(datetime[1])
    elif "hrs" in x:
        time.append(x)
        date.append("N/A")
    else:
        date.append(x)
        time.append("N/A")

df2021['Date']=date
df2021['Time']=time
#separating lat, long and description
lat = []
long = []
des = []

for x in df2021["latlong"]:
    
    if "' E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long.append(latl[1].split("' E", 1)[0]+"' E")
            des.append(latl[1].split("' E", 1)[1])
        else:
            long.append(ket)
            des.append("N/A")
    elif "’ E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        long.append(latl[1].split("’ E", 1)[0]+"’ E")
        des.append(latl[1].split("’ E", 1)[1])
    else:
        lat.append("N/A")
        long.append("N/A")
        des.append(x)
len(lat)
len(long)
len(des)
df2021['Latitude']=lat
df2021['Longitude']=long
df2021['Description']=des

df2021['Latitude']=df2021['Latitude'].str.replace("\'", "'")
df2021['Latitude'].head()
df2021['Longitude']=df2021['Longitude'].str.replace("\n", "")
df2021['Longitude']=df2021['Longitude'].str.replace("\'", "'")

df2021['Description']=df2021['Description'].str.replace("\n", " ")
df2021['Description']=df2021['Description'].str.replace("\'", "'")

for x in range(0, len(df2021["Latitude"])):
    if df2021["Latitude"][x]=="N/A":
        print(x)
        print(df2021["Description"][x])




df2021.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2021.xlsx")

# %%
#2018
a=[]
b=[] #cat
c=[] #name
d=[] #datetime
e=[] #latlong
f=0

for f in range(len(df2020a)):
    itemb = ""
    itemc = ""
    itemd = ""
    iteme = ""

    while f + 1 < len(df2020a) and df2020a[0][f+1] == df2020a[0][f]:   
        itemb += str(df2020a[1][f])
        itemc += str(df2020a[2][f])
        itemd += str(df2020a[3][f])
        iteme += str(df2020a[4][f])
        f += 1

    if f + 1 < len(df2020a) and df2020a[0][f+1] != df2020a[0][f]: 
        itema = df2020a[0][f]  
        itemb += str(df2020a[1][f])
        itemc += str(df2020a[2][f])
        itemd += str(df2020a[3][f])
        iteme += str(df2020a[4][f])

        a.append(itema)   
        b.append(itemb)
        c.append(itemc)
        d.append(itemd)
        e.append(iteme)
        

aa=[]
bb=[]
cc=[]
dd=[]
ee=[]
for aaa, bbb, ccc, ddd, eee in zip(a, b, c, d, e):
    if aaa not in aa:
        aa.append(aaa)
        bb.append(bbb)
        cc.append(ccc)
        dd.append(ddd)
        ee.append(eee)

df2020=pd.DataFrame()
df2020["CAT"]=bb
df2020["CAT"]=df2020["CAT"].str.replace("None", "")
df2020["name"]=cc
df2020["name"]=df2020["name"].str.replace("None", "")
df2020["datetime"]=dd
df2020["datetime"]=df2020["datetime"].str.replace("None", "").str.replace("00:00:00", "")
df2020["latlong"]=ee
df2020["latlong"]=df2020["latlong"].str.replace("None", "")


#separating date and time + creating datetime
list=[]
date=[]
time=[]
for x in df2020["datetime"]:
    if '\n' in x:
        datetime=x.split('\n')
        date.append(datetime[0])
        time.append(datetime[1])
    elif " " in x:
        datetime=x.split(' ', 1)
        date.append(datetime[0])
        time.append(datetime[1])
    elif "hrs" in x:
        time.append(x)
        date.append("N/A")
    else:
        date.append(x)
        time.append("N/A")

df2020['Date']=date
df2020['Time']=time
#separating lat, long and description
lat = []
long = []
des = []

for x in df2020["latlong"]:
    
    if "' E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long.append(latl[1].split("' E", 1)[0]+"' E")
            des.append(latl[1].split("' E", 1)[1])
        else:
            long.append(ket)
            des.append("N/A")
    elif "’ E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        long.append(latl[1].split("’ E", 1)[0]+"’ E")
        des.append(latl[1].split("’ E", 1)[1])
    else:
        lat.append("N/A")
        long.append("N/A")
        des.append(x)
len(lat)
len(long)
len(des)
df2020['Latitude']=lat
df2020['Longitude']=long
df2020['Description']=des

df2020['Latitude']=df2020['Latitude'].str.replace("\'", "'")
df2020['Latitude'].head()
df2020['Longitude']=df2020['Longitude'].str.replace("\n", "")
df2020['Longitude']=df2020['Longitude'].str.replace("\'", "'")

df2020['Description']=df2020['Description'].str.replace("\n", " ")
df2020['Description']=df2020['Description'].str.replace("\'", "'")


df2020.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2020.xlsx")

# %%
#2018
a=[]
b=[] #cat
c=[] #name
d=[] #datetime
e=[] #latlong
f=0

for f in range(len(df2018a)):
    itemb = ""
    itemc = ""
    itemd = ""
    iteme = ""

    while f + 1 < len(df2018a) and df2018a[0][f+1] == df2018a[0][f]:   
        itemb += str(df2018a[1][f])
        itemc += str(df2018a[2][f])
        itemd += str(df2018a[3][f])
        iteme += str(df2018a[4][f])
        f += 1


    if f + 1 < len(df2018a) and df2018a[0][f+1] != df2018a[0][f]: 
        itema = df2018a[0][f]  
        itemb += str(df2018a[1][f])
        itemc += str(df2018a[2][f])
        itemd += str(df2018a[3][f])
        iteme += str(df2018a[4][f])

        a.append(itema)   
        b.append(itemb)
        c.append(itemc)
        d.append(itemd)
        e.append(iteme)
        

aa=[]
bb=[]
cc=[]
dd=[]
ee=[]
for aaa, bbb, ccc, ddd, eee in zip(a, b, c, d, e):
    if aaa not in aa:
        aa.append(aaa)
        bb.append(bbb)
        cc.append(ccc)
        dd.append(ddd)
        ee.append(eee)

df2018=pd.DataFrame()
df2018["CAT"]=bb
df2018["CAT"]=df2018["CAT"].str.replace("None", "")
df2018["name"]=cc
df2018["name"]=df2018["name"].str.replace("None", "")
df2018["datetime"]=dd
df2018["datetime"]=df2018["datetime"].str.replace("None", "").str.replace("00:00:00", "")
df2018["latlong"]=ee
df2018["latlong"]=df2018["latlong"].str.replace("None", "")



#separating date and time + creating datetime
list=[]
date=[]
time=[]
for x in df2018["datetime"]:
    if '\n' in x:
        datetime=x.split('\n')
        date.append(datetime[0])
        time.append(datetime[1])
    elif " " in x:
        datetime=x.split(' ', 1)
        date.append(datetime[0])
        time.append(datetime[1])
    elif "hrs" in x:
        time.append(x)
        date.append("N/A")
    else:
        date.append(x)
        time.append("N/A")

df2018['Date']=date
df2018['Time']=time
#separating lat, long and description
lat = []
long = []
des = []

for x in df2018["latlong"]:
    
    if "' E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long.append(latl[1].split("' E", 1)[0]+"' E")
            des.append(latl[1].split("' E", 1)[1])
        else:
            long.append(ket)
            des.append("N/A")
    elif "’ E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        long.append(latl[1].split("’ E", 1)[0]+"’ E")
        des.append(latl[1].split("’ E", 1)[1])
    else:
        lat.append("N/A")
        long.append("N/A")
        des.append(x)
len(lat)
len(long)
len(des)
df2018['Latitude']=lat
df2018['Longitude']=long
df2018['Description']=des

df2018['Latitude']=df2018['Latitude'].str.replace("\'", "'")
df2018['Latitude'].head()
df2018['Longitude']=df2018['Longitude'].str.replace("\n", "")
df2018['Longitude']=df2018['Longitude'].str.replace("\'", "'")

df2018['Description']=df2018['Description'].str.replace("\n", " ")
df2018['Description']=df2018['Description'].str.replace("\'", "'")
           


df2018.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2018.xlsx")

# %%
df2014a.head()
a=[]
b=[] #cat
c=[] #name
d=[] #datetime
e=[] #latlong
f=0

for f in range(0, len(df2014a)-1):
    itemb=""
    itemc=""
    itemd=""
    iteme=""
    while df2014a[0][f+1]==df2014a[0][f]:   
        itemb=str(itemb)+str(df2014a[1][f])
        itemc=itemc+str(df2014a[2][f])
        itemd=str(itemd)+str(df2014a[3][f])
        iteme=str(iteme)+str(df2014a[4][f])
        f=f+1

    if df2014a[0][f+1]!=df2014a[0][f]: 
        itema=df2014a[0][f]  
        itemb=str(itemb)+str(df2014a[1][f])
        itemc=itemc+str(df2014a[2][f])
        itemd=str(itemd)+str(df2014a[3][f])
        iteme=str(iteme)+str(df2014a[4][f])
        a.append(itema)   
        b.append(itemb)
        c.append(itemc)
        d.append(itemd)
        e.append(iteme)
        itema=0
        itemb=""
        itemc=""
        itemd=""
        iteme=""

aa=[]
bb=[]
cc=[]
dd=[]
ee=[]
for aaa, bbb, ccc, ddd, eee in zip(a, b, c, d, e):
    if aaa not in aa:
        aa.append(aaa)
        bb.append(bbb)
        cc.append(ccc)
        dd.append(ddd)
        ee.append(eee)


df2014=pd.DataFrame()
df2014["CAT"]=bb
df2014["CAT"]=df2014["CAT"].str.replace("None", "")
df2014["name"]=cc
df2014["name"]=df2014["name"].str.replace("None", "")
df2014["datetime"]=dd
df2014["datetime"]=df2014["datetime"].str.replace("None", "").str.replace("00:00:00", "")
df2014["latlong"]=ee
df2014["latlong"]=df2014["latlong"].str.replace("None", "")

df2014.head()

    

#separating date and time + creating datetime
list=[]
date=[]
time=[]
for x in df2014["datetime"]:
    if '\n' in x:
        datetime=x.split('\n')
        date.append(datetime[0])
        time.append(datetime[1])
    elif " " in x:
        datetime=x.split(' ', 1)
        date.append(datetime[0])
        time.append(datetime[1])
    elif "hrs" in x:
        time.append(x)
        date.append("N/A")
    else:
        date.append(x)
        time.append("N/A")

df2014['Date']=date
df2014['Time']=time
#separating lat, long and description
lat = []
long = []
des = []

for x in df2014["latlong"]:
    
    if "' E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long.append(latl[1].split("' E", 1)[0]+"' E")
            des.append(latl[1].split("' E", 1)[1])
        else:
            long.append(ket)
            des.append("N/A")
    elif "’ E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        long.append(latl[1].split("’ E", 1)[0]+"’ E")
        des.append(latl[1].split("’ E", 1)[1])
    else:
        lat.append("N/A")
        long.append("N/A")
        des.append(x)
len(lat)
len(long)
len(des)
df2014['Latitude']=lat
df2014['Longitude']=long
df2014['Description']=des

df2014['Latitude']=df2014['Latitude'].str.replace("\'", "'")
df2014['Latitude'].head()
df2014['Longitude']=df2014['Longitude'].str.replace("\n", "")
df2014['Longitude']=df2014['Longitude'].str.replace("\'", "'")

df2014['Description']=df2014['Description'].str.replace("\n", " ")
df2014['Description']=df2014['Description'].str.replace("\'", "'")
           
df2014.head()


for x in range(0, len(df2014["Latitude"])):
    if df2014["Latitude"][x]=="N/A":
        print(x)
        print(df2014["Description"][x])

df2014.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2014.xlsx")
# Out:
# 64
# scs
# 80
# Tanjung Priok Anchorage, Indonesia
# 96
# Chittagong anchorage, Bangladesh
# 121
# Sampit, Central Kalimantan, Indonesia

# %%
df2013a.head()
a=[]
b=[] #cat
c=[] #name
d=[] #datetime
e=[] #latlong
f=0

for f in range(len(df2013a)):
    itemb=""
    itemc=""
    itemd=""
    iteme=""
    while f+1<len(df2013a) and df2013a[0][f+1]==df2013a[0][f]:   
        itemb=str(itemb)+str(df2013a[1][f])
        itemc=itemc+str(df2013a[2][f])
        itemd=str(itemd)+str(df2013a[3][f])
        iteme=str(iteme)+str(df2013a[4][f])
        f=f+1

    if f+1<len(df2013a) and df2013a[0][f+1]!=df2013a[0][f]: 
        itema=df2013a[0][f]  
        itemb=str(itemb)+str(df2013a[1][f])
        itemc=itemc+str(df2013a[2][f])
        itemd=str(itemd)+str(df2013a[3][f])
        iteme=str(iteme)+str(df2013a[4][f])
        a.append(itema)   
        b.append(itemb)
        c.append(itemc)
        d.append(itemd)
        e.append(iteme)
        itema=0
        itemb=""
        itemc=""
        itemd=""
        iteme=""

aa=[]
bb=[]
cc=[]
dd=[]
ee=[]
for aaa, bbb, ccc, ddd, eee in zip(a, b, c, d, e):
    if aaa not in aa:
        aa.append(aaa)
        bb.append(bbb)
        cc.append(ccc)
        dd.append(ddd)
        ee.append(eee)


df2013=pd.DataFrame()
df2013["CAT"]=bb
df2013["CAT"]=df2013["CAT"].str.replace("None", "")
df2013["name"]=cc
df2013["name"]=df2013["name"].str.replace("None", "")
df2013["datetime"]=dd
df2013["datetime"]=df2013["datetime"].str.replace("None", "").str.replace("00:00:00", "")
df2013["latlong"]=ee
df2013["latlong"]=df2013["latlong"].str.replace("None", "")

df2013.head()

    

#separating date and time + creating datetime
list=[]
date=[]
time=[]
for x in df2013["datetime"]:
    if '\n' in x:
        datetime=x.split('\n')
        date.append(datetime[0])
        time.append(datetime[1])
    elif " " in x:
        datetime=x.split(' ', 1)
        date.append(datetime[0])
        time.append(datetime[1])
    elif "hrs" in x:
        time.append(x)
        date.append("N/A")
    else:
        date.append(x)
        time.append("N/A")

df2013['Date']=date
df2013['Time']=time
#separating lat, long and description
lat = []
long = []
des = []

for x in df2013["latlong"]:
    
    if "' E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long.append(latl[1].split("' E", 1)[0]+"' E")
            des.append(latl[1].split("' E", 1)[1])
        else:
            long.append(ket)
            des.append("N/A")
    elif "’ E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        long.append(latl[1].split("’ E", 1)[0]+"’ E")
        des.append(latl[1].split("’ E", 1)[1])
    else:
        lat.append("N/A")
        long.append("N/A")
        des.append(x)
len(lat)
len(long)
len(des)
df2013['Latitude']=lat
df2013['Longitude']=long
df2013['Description']=des

df2013['Latitude']=df2013['Latitude'].str.replace("\'", "'")
df2013['Latitude'].head()
df2013['Longitude']=df2013['Longitude'].str.replace("\n", "")
df2013['Longitude']=df2013['Longitude'].str.replace("\'", "'")

df2013['Description']=df2013['Description'].str.replace("\n", " ")
df2013['Description']=df2013['Description'].str.replace("\'", "'")
           


for x in range(0, len(df2013["Latitude"])):
    if df2013["Latitude"][x]=="N/A":
        print(x)
        print(df2013["Description"][x])


df2013.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2013.xlsx")
# Out:
# 28
# Chittagong 'A' anchorage, Bangladesh
# 33
# Cam Pha outer anchorage, Vietnam
# 39
# Berth Ocean Quay 106, Belawan Port, Indonesia
# 92
# Samarinda anchorage, East Kalimantan, Indonesia
# 97
# Karimun Transhipment area
# 124
# Dumai port, Indonesia
# 126
# Belawan anchorage, Indonesia

# %%
df2019a.head()
a=[]
b=[] #cat
c=[] #name
d=[] #datetime
e=[] #latlong
f=0

for f in range(len(df2019a)):
    itemb=""
    itemc=""
    itemd=""
    iteme=""
    while f+1<len(df2019a) and df2019a[0][f+1]==df2019a[0][f]:   
        itemb=str(itemb)+str(df2019a[1][f])
        itemc=itemc+str(df2019a[2][f])
        itemd=str(itemd)+str(df2019a[3][f])
        iteme=str(iteme)+str(df2019a[4][f])
        f=f+1

    if f+1<len(df2019a) and df2019a[0][f+1]!=df2019a[0][f]: 
        itema=df2019a[0][f]  
        itemb=str(itemb)+str(df2019a[1][f])
        itemc=itemc+str(df2019a[2][f])
        itemd=str(itemd)+str(df2019a[3][f])
        iteme=str(iteme)+str(df2019a[4][f])
        a.append(itema)   
        b.append(itemb)
        c.append(itemc)
        d.append(itemd)
        e.append(iteme)
        itema=0
        itemb=""
        itemc=""
        itemd=""
        iteme=""

aa=[]
bb=[]
cc=[]
dd=[]
ee=[]
for aaa, bbb, ccc, ddd, eee in zip(a, b, c, d, e):
    if aaa not in aa:
        aa.append(aaa)
        bb.append(bbb)
        cc.append(ccc)
        dd.append(ddd)
        ee.append(eee)


df2019=pd.DataFrame()
df2019["CAT"]=bb
df2019["CAT"]=df2019["CAT"].str.replace("None", "")
df2019["name"]=cc
df2019["name"]=df2019["name"].str.replace("None", "")
df2019["datetime"]=dd
df2019["datetime"]=df2019["datetime"].str.replace("None", "").str.replace("00:00:00", "")
df2019["latlong"]=ee
df2019["latlong"]=df2019["latlong"].str.replace("None", "")

df2019.head()

    
#separating date and time + creating datetime
list=[]
date=[]
time=[]
for x in df2019["datetime"]:
    if '\n' in x:
        datetime=x.split('\n')
        date.append(datetime[0])
        time.append(datetime[1])
    elif " " in x:
        datetime=x.split(' ', 1)
        date.append(datetime[0])
        time.append(datetime[1])
    elif "hrs" in x:
        time.append(x)
        date.append("N/A")
    else:
        date.append(x)
        time.append("N/A")

df2019['Date']=date
df2019['Time']=time
#separating lat, long and description
lat = []
long = []
des = []

for x in df2019["latlong"]:
    
    if "' E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long.append(latl[1].split("' E", 1)[0]+"' E")
            des.append(latl[1].split("' E", 1)[1])
        else:
            long.append(ket)
            des.append("N/A")
    elif "’ E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        long.append(latl[1].split("’ E", 1)[0]+"’ E")
        des.append(latl[1].split("’ E", 1)[1])
    else:
        lat.append("N/A")
        long.append("N/A")
        des.append(x)
len(lat)
len(long)
len(des)
df2019['Latitude']=lat
df2019['Longitude']=long
df2019['Description']=des

df2019['Latitude']=df2019['Latitude'].str.replace("\'", "'")
df2019['Latitude'].head()
df2019['Longitude']=df2019['Longitude'].str.replace("\n", "")
df2019['Longitude']=df2019['Longitude'].str.replace("\'", "'")

df2019['Description']=df2019['Description'].str.replace("\n", " ")
df2019['Description']=df2019['Description'].str.replace("\'", "'")
           


for x in range(0, len(df2019["Latitude"])):
    if df2019["Latitude"][x]=="N/A":
        print(x)
        print(df2019["Description"][x])

df2019.head()

df2019.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2019.xlsx")
# Out:
# 42
# Sandakan Port, Malaysia

# %%
#2016
df2016a.head()
a=[]
b=[] #cat
c=[] #name
d=[] #datetime
e=[] #latlong
f=0

for f in range(0, len(df2016a)-1):
    itemb=""
    itemc=""
    itemd=""
    iteme=""
    while df2016a[0][f+1]==df2016a[0][f]:   
        itemb=str(itemb)+str(df2016a[1][f])
        itemc=itemc+str(df2016a[2][f])
        itemd=str(itemd)+str(df2016a[3][f])
        iteme=str(iteme)+str(df2016a[4][f])
        f=f+1

    if df2016a[0][f+1]!=df2016a[0][f]: 
        itema=df2016a[0][f]  
        itemb=str(itemb)+str(df2016a[1][f])
        itemc=itemc+str(df2016a[2][f])
        itemd=str(itemd)+str(df2016a[3][f])
        iteme=str(iteme)+str(df2016a[4][f])
        a.append(itema)   
        b.append(itemb)
        c.append(itemc)
        d.append(itemd)
        e.append(iteme)
        itema=0
        itemb=""
        itemc=""
        itemd=""
        iteme=""

aa=[]
bb=[]
cc=[]
dd=[]
ee=[]
for aaa, bbb, ccc, ddd, eee in zip(a, b, c, d, e):
    if aaa not in aa:
        aa.append(aaa)
        bb.append(bbb)
        cc.append(ccc)
        dd.append(ddd)
        ee.append(eee)


df2016=pd.DataFrame()
df2016["CAT"]=bb
df2016["CAT"]=df2016["CAT"].str.replace("None", "")
df2016["name"]=cc
df2016["name"]=df2016["name"].str.replace("None", "")
df2016["datetime"]=dd
df2016["datetime"]=df2016["datetime"].str.replace("None", "").str.replace("00:00:00", "")
df2016["latlong"]=ee
df2016["latlong"]=df2016["latlong"].str.replace("None", "")

df2016.head()
#separating date and time + creating datetime
list=[]
date=[]
time=[]
for x in df2016["datetime"]:
    if '\n' in x:
        datetime=x.split('\n')
        date.append(datetime[0])
        time.append(datetime[1])
    elif " " in x:
        datetime=x.split(' ', 1)
        date.append(datetime[0])
        time.append(datetime[1])
    elif "hrs" in x:
        time.append(x)
        date.append("N/A")
    else:
        date.append(x)
        time.append("N/A")

df2016['Date']=date
df2016['Time']=time
#separating lat, long and description
lat = []
long = []
des = []

for x in df2016["latlong"]:
    
    if "' E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long.append(latl[1].split("' E", 1)[0]+"' E")
            des.append(latl[1].split("' E", 1)[1])
        else:
            long.append(ket)
            des.append("N/A")
    elif "’ E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        long.append(latl[1].split("’ E", 1)[0]+"’ E")
        des.append(latl[1].split("’ E", 1)[1])
    else:
        lat.append("N/A")
        long.append("N/A")
        des.append(x)
len(lat)
len(long)
len(des)
df2016['Latitude']=lat
df2016['Longitude']=long
df2016['Description']=des

df2016['Latitude']=df2016['Latitude'].str.replace("\'", "'")
df2016['Latitude'].head()
df2016['Longitude']=df2016['Longitude'].str.replace("\n", "")
df2016['Longitude']=df2016['Longitude'].str.replace("\'", "'")

df2016['Description']=df2016['Description'].str.replace("\n", " ")
df2016['Description']=df2016['Description'].str.replace("\'", "'")
           


for x in range(0, len(df2016["Latitude"])):
    if df2016["Latitude"][x]=="N/A":
        print(x)
        print(df2016["Description"][x])

    

df2016.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2016.xlsx")
# Out:
# 5
# Kandla anchorage, India
# 9
# Kandla anchorage, India
# 14
# Jakarta anchorage, Indonesia
# 32
# Off Pulau Belitung, Indonesia
# 44
# Approximately 8 nm off east coast of Lahad Datu, Sabah, Malaysia
# 61
# South China Sea

# %%
#2012
df2012a.head()
a=[]
b=[] #cat
c=[] #name
d=[] #datetime
e=[] #latlong
f=0

for f in range(0, len(df2012a)-1):
    itemb=""
    itemc=""
    itemd=""
    iteme=""
    while df2012a[0][f+1]==df2012a[0][f]:   
        itemb=str(itemb)+str(df2012a[1][f])
        itemc=itemc+str(df2012a[2][f])
        itemd=str(itemd)+str(df2012a[3][f])
        iteme=str(iteme)+str(df2012a[4][f])
        f=f+1

    if df2012a[0][f+1]!=df2012a[0][f]: 
        itema=df2012a[0][f]  
        itemb=str(itemb)+str(df2012a[1][f])
        itemc=itemc+str(df2012a[2][f])
        itemd=str(itemd)+str(df2012a[3][f])
        iteme=str(iteme)+str(df2012a[4][f])
        a.append(itema)   
        b.append(itemb)
        c.append(itemc)
        d.append(itemd)
        e.append(iteme)
        itema=0
        itemb=""
        itemc=""
        itemd=""
        iteme=""

aa=[]
bb=[]
cc=[]
dd=[]
ee=[]
for aaa, bbb, ccc, ddd, eee in zip(a, b, c, d, e):
    if aaa not in aa:
        aa.append(aaa)
        bb.append(bbb)
        cc.append(ccc)
        dd.append(ddd)
        ee.append(eee)



df2012=pd.DataFrame()
df2012["CAT"]=bb
df2012["CAT"]=df2012["CAT"].str.replace("None", "")
df2012["name"]=cc
df2012["name"]=df2012["name"].str.replace("None", "")
df2012["datetime"]=dd
df2012["datetime"]=df2012["datetime"].str.replace("None", "").str.replace("00:00:00", "")
df2012["latlong"]=ee
df2012["latlong"]=df2012["latlong"].str.replace("None", "")

df2012.head()

    

#separating date and time + creating datetime
list=[]
date=[]
time=[]
for x in df2012["datetime"]:
    if '\n' in x:
        datetime=x.split('\n')
        date.append(datetime[0])
        time.append(datetime[1])
    elif " " in x:
        datetime=x.split(' ', 1)
        date.append(datetime[0])
        time.append(datetime[1])
    elif "hrs" in x:
        time.append(x)
        date.append("N/A")
    else:
        date.append(x)
        time.append("N/A")

df2012['Date']=date
df2012['Time']=time
#separating lat, long and description
lat = []
long = []
des = []

for x in df2012["latlong"]:
    
    if "' E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long.append(latl[1].split("' E", 1)[0]+"' E")
            des.append(latl[1].split("' E", 1)[1])
        else:
            long.append(ket)
            des.append("N/A")
    elif "’ E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        long.append(latl[1].split("’ E", 1)[0]+"’ E")
        des.append(latl[1].split("’ E", 1)[1])
    else:
        lat.append("N/A")
        long.append("N/A")
        des.append(x)
len(lat)
len(long)
len(des)
df2012['Latitude']=lat
df2012['Longitude']=long
df2012['Description']=des

df2012['Latitude']=df2012['Latitude'].str.replace("\'", "'")
df2012['Latitude'].head()
df2012['Longitude']=df2012['Longitude'].str.replace("\n", "")
df2012['Longitude']=df2012['Longitude'].str.replace("\'", "'")

df2012['Description']=df2012['Description'].str.replace("\n", " ")
df2012['Description']=df2012['Description'].str.replace("\'", "'")
           



for x in range(0, len(df2012["Latitude"])):
    if df2012["Latitude"][x]=="N/A":
        print(x)
        print(df2012["Description"][x])

        
df2012.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2012.xlsx")
# Out:
# 2
# ManilaInternationalContainerTerminal (MICT)Anchorage Area,North Harbor,Philippines
# 3
# Jakarta Roads,Indonesia
# 15
# Off  Karimun Transhipment area, Indonesia
# 32
# Balikpapan Inner Anchorage, Indonesia
# 43
# Approximately 35 nm off Tanjung Dato,Sarawak,Malaysia (SouthChina Sea)
# 50
# Off Talicud Island, Philippines
# 54
# Approximately 30 nm off Horsburgh Lighthouse, Singapore (South China Sea)
# 57
# Kuching Anchorage, Malaysia
# 60
# Off Tanjung Lobang, Miri, Sarawak,Malaysia
# 62
# Approximately 5.4 nm off the coast ofMiri, Sarawak,Malaysia
# 65
# Between Kadut and Pulau Banggi, Sabah, Malaysia
# 67
# Dumai Anchorage, Indonesia
# 85
# Chittagong Anchorage, Bangladesh
# 89
# Belawan Anchorage, Indonesia
# 123
# Ho Chi Minh container terminal, Vietnam

# %%
#2010
df2010.head()
#vertical concat

#separating date and time + creating datetime
list=[]
date=[]
time=[]
for x in df2010[3]:
    if '\n' in x:
        datetime=x.split('\n')
        date.append(datetime[0])
        time.append(datetime[1])
    elif " " in x:
        datetime=x.split(' ', 1)
        date.append(datetime[0])
        time.append(datetime[1])
    elif "hrs" in x:
        time.append(x)
        date.append("N/A")
    else:
        date.append(x)
        time.append("N/A")

df2010['Date']=date
df2010['Time']=time
#separating lat, long and description
lat = []
long = []
des = []

for x in df2010[4]:
    
    if "' E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long.append(latl[1].split("' E", 1)[0]+"' E")
            des.append(latl[1].split("' E", 1)[1])
        else:
            long.append(ket)
            des.append("N/A")
    elif "’ E" in x and "," in x:
        latl=x.split(",", 1)
        lat.append(latl[0])
        long.append(latl[1].split("’ E", 1)[0]+"’ E")
        des.append(latl[1].split("’ E", 1)[1])
    else:
        lat.append("N/A")
        long.append("N/A")
        des.append(x)
len(lat)
len(long)
len(des)
df2010['Latitude']=lat
df2010['Longitude']=long
df2010['Description']=des

df2010['Latitude']=df2010['Latitude'].str.replace("\'", "'")
df2010['Latitude'].head()
df2010['Longitude']=df2010['Longitude'].str.replace("\n", "")
df2010['Longitude']=df2010['Longitude'].str.replace("\'", "'")

df2010['Description']=df2010['Description'].str.replace("\n", " ")
df2010['Description']=df2010['Description'].str.replace("\'", "'")

df2010.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2010.xlsx")

# %%
#2017
list=[]
date17=[]
time17=[]
lat17 = []
long17 = []
des17 = []

df2017[3]=df2017[3].str.replace("\n", " ")
for x in df2017[3]:
    datetime=str(x).split(" ", 1)
    if len(datetime)>1:
        date17.append(datetime[0])
        time17.append(datetime[1])
    elif "hrs" in str(x):
        date17.append("N/A")        
        time17.append(x)
    else:
        date17.append(x)
        time17.append("N/A")
        
df2017["Date"]=date17
df2017["Time"]=time17
#lat-long
#df2017[4]=df2017[4].str.replace("\n", " ")

df2017.head()
df2017[4]=df2017[4].str.replace("\n", " ")
df2017[4]=df2017[4].str.replace("\'", "'")
df2017[4].head()
for x in df2017[4]:
    if "' E" in str(x) and "," in str(x):
        latl=str(x).split(",", 1)
        lat17.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long17.append(latl[1].split("' E", 1)[0]+"' E")
            des17.append(latl[1].split("' E", 1)[1])
        else:
            long17.append(ket)
            des17.append("N/A")
    elif "’ E" in str(x) and "," in str(x):
        latl=x.split(",", 1)
        lat17.append(latl[0])
        long17.append(latl[1].split("’ E", 1)[0]+"’ E")
        des17.append(latl[1].split("’ E", 1)[1])
    else:
        lat17.append("N/A")
        long17.append("N/A")
        des17.append(x)

df2017['Latitude']=lat17 
df2017['Longitude']=long17
df2017['Description']=des17
df2017['Latitude']=df2017['Latitude'].str.replace("\'", "'")
df2017['Latitude']=df2017['Latitude'].str.replace("\n", "")
df2017['Longitude']=df2017['Longitude'].str.replace("\'", "'")
df2017['Longitude']=df2017['Longitude'].str.replace("\n", "")
df2017['Description']=df2017['Description'].str.replace("\'", "'")
df2017['Description']=df2017['Description'].str.replace("\n", "")

df2017.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2017.xlsx")

# %%
list=[]
date15=[]
time15=[]
lat15 = []
long15 = []
des15 = []

df2015[3]=df2015[3].str.replace("\n", " ")
for x in df2015[3]:
    datetime=str(x).split(" ", 1)
    if len(datetime)>1:
        date15.append(datetime[0])
        time15.append(datetime[1])
    elif "hrs" in str(x):
        date15.append("N/A") 
        time15.append(x)
    else:
        date15.append(x)
        time15.append("N/A")

df2015["Date"]=date15
df2015["Time"]=time15
#lat-long
#df2015[4]=df2015[4].str.replace("\n", " ")

df2015.head()
df2015[4]=df2015[4].str.replace("\n", " ")
df2015[4]=df2015[4].str.replace("\'", "'")
df2015[4].head()
for x in df2015[4]:
    if "' E" in str(x) and "," in str(x):
        latl=str(x).split(",", 1)
        lat15.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long15.append(latl[1].split("' E", 1)[0]+"' E")
            des15.append(latl[1].split("' E", 1)[1])
        else:
            long15.append(ket)
            des15.append("N/A")
    elif "’ E" in str(x) and "," in str(x):
        latl=x.split(",", 1)
        lat15.append(latl[0])
        long15.append(latl[1].split("’ E", 1)[0]+"’ E")
        des15.append(latl[1].split("’ E", 1)[1])
    else:
        lat15.append("N/A")
        long15.append("N/A")
        des15.append(x)

df2015['Latitude']=lat15 
df2015['Longitude']=long15
df2015['Description']=des15
df2015['Latitude']=df2015['Latitude'].str.replace("\'", "'")
df2015['Latitude']=df2015['Latitude'].str.replace("\n", "")
df2015['Longitude']=df2015['Longitude'].str.replace("\'", "'")
df2015['Longitude']=df2015['Longitude'].str.replace("\n", "")
df2015['Description']=df2015['Description'].str.replace("\'", "'")
df2015['Description']=df2015['Description'].str.replace("\n", "")

df2015.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2015.xlsx")

# %%
#2011
list=[]
date=[]
time=[]
lat11 = []
long11 = []
des11 = []

df2011[3]=df2011[3].str.replace("\n", " ")
for x in df2011[3]:
    datetime=str(x).split(" ", 1)
    if len(datetime)>1:
        date.append(datetime[0])
        time.append(datetime[1])
    elif "hrs" in str(x):
        date.append("N/A")
        
        time.append(x)
    else:
        date.append(x)
        time.append("N/A")
        
df2011["Date"]=date
df2011["Time"]=time
#lat-long
df2011[4]=df2011[4].str.replace("\n", " ")
df2011[4]=df2011[4].str.replace("\'", "'")
df2011[4].head()
for x in df2011[4]:
    if "' E" in str(x) and "," in str(x):
        latl=str(x).split(",", 1)
        lat11.append(latl[0])
        ket=latl[1].split("' E", 1)

        if len(ket)>1:
            long11.append(latl[1].split("' E", 1)[0]+"' E")
            des11.append(latl[1].split("' E", 1)[1])
        else:
            long11.append(ket)
            des11.append("N/A")
    elif "’ E" in str(x) and "," in str(x):
        latl=x.split(",", 1)
        lat11.append(latl[0])
        long11.append(latl[1].split("’ E", 1)[0]+"’ E")
        des11.append(latl[1].split("’ E", 1)[1])
    else:
        lat11.append("N/A")
        long11.append("N/A")
        des11.append(x)

df2011['Latitude']=lat11
df2011['Longitude']=long11
df2011['Description']=des11
df2011['Latitude']=df2011['Latitude'].str.replace("\'", "'")
df2011['Latitude']=df2011['Latitude'].str.replace("\n", "")
df2011['Longitude']=df2011['Longitude'].str.replace("\'", "'")
df2011['Longitude']=df2011['Longitude'].str.replace("\n", "")
df2011['Description']=df2011['Description'].str.replace("\'", "'")
df2011['Description']=df2011['Description'].str.replace("\n", "")

df2011.to_excel("C:\\Users\\Andris\\Documents\\Szakdoga\\df\\df2011.xlsx")
